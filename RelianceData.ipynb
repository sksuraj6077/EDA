# %%
import requests
import pandas as pd

# %%
header1 = {
    'Accept':'application/json, text/javascript, */*; q=0.01',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'en-US,en;q=0.9',
    'Cookie':'nsit=QbZgUagoR8Quqlq8ooEXR12Q; AKA_A2=A; defaultLang=en; ak_bmsc=EB87E8801DD385A09318FCC5265731D1~000000000000000000000000000000~...; nseQuoteSymbols=[{"symbol":"RELIANCE","identifier":null,"type":"equity"}]; _gid=GA1.2.757683872.1692880132; nseappid=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJhcGkubnNlIiwiYXVkIjoiYXBpLm5zZSIsImlhdCI6MTY5Mjg4MDI5MSwiZXhwIjoxNjkyODg3NDkxfQ.T4cd6gwehjOXtKgPq_vuHVHcaaJruWwuQhDOp98C0ZA; RT="z=1&dm=nseindia.com&si=73f0ee70-83af-4f68-90e5-da1054e717be&ss=llp53xz2&sl=2&se=8c&tt=79m&bcn=%2F%2F684d0d4c.akstat.io%2F"; _ga_PJSKY6CFJH=GS1.1.1692880115.1.1.1692880292.59.0.0; _ga=GA1.1.1718667660.1692880115; bm_sv=E4A78C4D325F3C73B6048E3C97B24148~~1',
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36',
    'X-Requested-With':'XMLHttpRequest'
}

# %%
response = requests.get(url='https://www.nseindia.com/api/chart-databyindex?index=RELIANCEEQN',headers=header1)

# %%
response
# Out:
# <Response [200]>

# %%
print(response.json()['grapthData'])
# Out:
# [[1692868500000, 2539.75], [1692868508000, 2535.6], [1692868516000, 2533.65], [1692868522000, 2532.75], [1692868529000, 2532.9], [1692868535000, 2532.9], [1692868541000, 2533], [1692868546000, 2532], [1692868552000, 2532.9], [1692868559000, 2532.9], [1692868565000, 2531.75], [1692868566000, 2531.6], [1692868567000, 2531.95], [1692868568000, 2532.3], [1692868569000, 2532.2], [1692868570000, 2531.8], [1692868571000, 2531.1], [1692868572000, 2531.95], [1692868573000, 2531.95], [1692868574000, 2531.9], [1692868575000, 2531.9], [1692868576000, 2531.7], [1692868577000, 2531.1], [1692868578000, 2531.2], [1692868579000, 2532.65], [1692868580000, 2532.2], [1692868581000, 2531.65], [1692868582000, 2532.75], [1692868613000, 2528], [1692868614000, 2527.55], [1692868615000, 2527.55], [1692868616000, 2527.2], [1692868617000, 2527.85], [1692868618000, 2529.15], [1692868619000, 2529.25], [1692868620000, 2529.25], [1692868621000, 2528.05], [1692868622000, 2528.3], [1692868623000, 2527.55], [169286862
# ...

# %%
Reliance = pd.DataFrame((response.json()['grapthData']))

# %%
Reliance.columns = ['Timestamp','Price']

# %%
Reliance['Timestamp'] = pd.to_datetime(Reliance['Timestamp'], unit = 'ms')

# %%
Reliance.to_csv('Reliance.csv')

# %%
import matplotlib as plt

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Reliance['Timestamp'],Reliance['Price'],color = 'red')
plt.figure().set_figwidth(100)
